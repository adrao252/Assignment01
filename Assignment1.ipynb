# %%
#q1
ans=0
x=0
count=0
c=0
def prime(x):
    count1=0  
    if(x==1):
        return 0
    
    elif(x==0):
        return 0
    
    else:
        for ii in range(2,x):
            if(x%ii)==0:
                count1=count1+1
                break
        
        if(count1==0):
            return 1
            
        elif(count1==1):
            return 0
    
for i in range(2,100):
    x1=len(str(i))
    w=i
    for t in range (x1):
        
        a=i%10
        b=(int(i/10))
        for j in range(1,x1):
            a=a*10
            
        a=a+b
        r=prime(a)
       
        if(r==1):
            c=c+1
           
         
        i=a
        a=0
        b=0
        
    if(c==x1):
        count=count+1
       
     
    i=w
    c=0

print(count)
# Out:
# 13

# %%
#q2
x=0
c=0
def prime(x):
    count1=0  
    if(x==1):
        return 0
    
    elif(x==0):
        return 0
    
    else:
        for ii in range(2,x):
            if(x%ii)==0:
                count1=count1+1
                break
        
        if(count1==0):
            return 1
            
        elif(count1==1):
            return 0
    
    
for i in range(100,2,-1):
    r1=prime(i)
    if(r1==1):
        for j in range (2,i):
            r=prime(j)
            if(r==1):
                x=x+j
                
            elif(x==i):
                c=1
            
            elif(x>i):
                break
        
    if(c==1):
        print(i)
        break
        
    x=0
# Out:
# 41

# %%
#q3
t=1
l=0
count=0
t1=1
d=1
i=10
x=0
sum1=0
def prime(x):
    count1=0  
    if(x==1):
        return 0
    
    elif(x==0):
        return 0
    
    else:
        for ii in range(2,x):
            if(x%ii)==0:
                count1=count1+1
                break
        
        if(count1==0):
            return 1
            
        elif(count1==1):
            return 0
    
    
    
while(count<10):
    r=prime(i)
    w=i
    if(r==1):
        l=len(str(w))
        for x in range(1,l):
            a=(int(i/10))
            r=prime(a)
            if(r==1):
                t=t+1
             
            else:
                break
                
            i=a
            
        i=w
        a=0
        for y in range(1,l):
            q=len(str(i))
            for p in range(1,q):
                d=d*10
                
            a=i%d
            r=prime(a)
            if(r==1):
                t1=t1+1
                
            i=a
            d=1
    
    
    i=w
    i=i+1
    a=0
    if(t==l and t1==l):
        print(i-1)
        count=count+1
        sum1=sum1+i
        
    d=1
    t=1
    t1=1

print(sum1)
# Out:
# 23
# 37
# 53
# 73
# 313
# 317
# 373
# 797
# 3137
# 3797
# 8930

# %%
#q4
r=0
count=0
def palindrome(num):
    n=num
    r=0
    while(n!=0):
        d=n%10
        r=(r*10)+d
        n=(int(n/10))
        
    if(num==r):
        return 1
    
    else:
        return 0

def reverse(num):
    n=num
    r=0
    while(n!=0):
        d=n%10
        r=(r*10)+d
        n=(int(n/10))
        
    return r


for i in range(10,10000):
    r1=palindrome(i)
    if(r==0):
        w=i
        for j in range(0,50):
            r2=reverse(i)
            x=i+r2
            r1=palindrome(x)
            if(r1==1):
                c=1
                break
                
            i=x
            
        if(c==0):
            count=count+1
            
        c=0
        r2=0
        x=0
        

        
print(count)
# Out:
# 249

# %%
#q5
import queue 

L = queue.Queue(maxsize=6) 

L.put(5) 
L.put(91) 
L.put(1) 
L.put(17)
L.put(71)
L.put(7)

s=L.qsize()
n1=L.get()
for i in range(1,s):
    n=L.get()
    if(n<n1):
        n1=n
        
print(n1)
# Out:
# 1
